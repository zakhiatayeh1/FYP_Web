# %%
# !pip install xgboost
# Out:
# ...
#                                               0.0/124.9 MB ? eta -:--:--
#                                               0.0/124.9 MB ? eta -:--:--
#                                               0.0/124.9 MB ? eta -:--:--
#                                               0.0/124.9 MB ? eta -:--:--
#                                             0.1/124.9 MB 469.7 kB/s eta 0:04:26
#                                             0.1/124.9 MB 469.7 kB/s eta 0:04:26
#                                             0.1/124.9 MB 403.5 kB/s eta 0:05:10
#                                             0.1/124.9 MB 403.5 kB/s eta 0:05:10
#                                             0.1/124.9 MB 364.4 kB/s eta 0:05:43
#                                             0.1/124.9 MB 359.9 kB/s eta 0:05:47
#                                             0.1/124.9 MB 359.9 kB/s eta 0:05:47
#                                             0.1/124.9 MB 359.9 kB/s eta 0:05:47
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 6
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 6 import xgboost as xgb
#       7 color_pal = sns.color_palette()
#       8 plt.style.use('fivethirtyeight')
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
df = pd.read_csv('sales_df.csv')
df.head()
# Out:
#            bike_name    bike_type date_ordered  quantity
# 0  BMX Freestyle Pro          BMX   2022-11-29        17
# 1  BMX Freestyle Pro          BMX   2021-11-22        19
# 2      AirMaster 300          BMX   2021-09-05         2
# 3     Roadmaster Pro    Road Bike   2023-07-30         8
# 4  UrbanCommuter 500  Hybrid Bike   2023-05-13         1

# %%
df.plot(style='.',figsize=(15,5),color=color_pal[0],title="bike sales")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.plot(style='.',figsize=(15,5),color=color_pal[0],title="bike sales")
#
# NameError: name 'color_pal' is not defined

# %%
df[df.date_ordered.year < 2023]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28184\1528072086.py in ?()
# ----> 1 df[df.date_ordered.year < 2023]
#
# c:\Users\souei\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
train = df[df.date_ordered.year < 2023]
test = df[df.date_ordered.year >= 2023]

fix,ax = plt.subplot(figsize=(15,5))
train.plot(ax=ax,label='Training Set')
test.plot(ax=ax,label='Test Set')
plt.show()

# %%
sns.boxplot(data=df,x='date_ordered',y='quantity')
